# %%
import tldextract
import pandas as pd
import json
import os
from tqdm import tqdm
from ftlangdetect import detect
from source_credibility import SourceCredibility

# Blacklists
BLACKLIST_DOMAINS = {
    "jstor.org",
    "facebook.com",
    "twitter.com",
    "x.com",
    "reddit.com",
    "linkedin.com",
    "threads.net",
    "quora.com",
    "tiktok.com",
    "instagram.com",
    "discord.com",
    "youtube.com",
    "spotify.com",
    "huggingface.co",
    "politifact.com",
    "snopes.com",
    "factcheck.org",
    "shutterstock.com",
    "naturepl.com",
    "example.com",
    "pinterest.com",
    "flickr.com",
    "twitch.tv",
    "verifythis.com",
    "telegram.org",
    "factcheck.africa",
    "washingtonpost.com",
    "reuters.com",
    "nytimes.com"
}

BLACKLIST_FILES = [
    "/glove.",
    "ftp://ftp.cs.princeton.edu/pub/cs226/autocomplete/words-333333.txt",
    "https://web.mit.edu/adamrose/Public/googlelist",
]

def get_domain_name(url):
    if '://' not in url:
        url = 'http://' + url
    extracted = tldextract.extract(url)
    return f"{extracted.domain}.{extracted.suffix}"

def should_filter_link(link):
    domain = get_domain_name(link)
    if domain in BLACKLIST_DOMAINS:
        return True
    if any(b_file in link for b_file in BLACKLIST_FILES):
        print("Blacklisted file: ", link)
        return True
    if link.endswith((".txt")):
        print("Blacklisted file type: ", link)
        return True
    return False

with open("../data/search_results.json", "r") as f:
    search_results = json.load(f)

credibility_checker = SourceCredibility()

if os.path.exists("../data/domain_credibility.json"):
    with open("../data/domain_credibility.json", "r") as f:
        domain_credibility = json.load(f)
else:
    domain_credibility = {}
print(len(domain_credibility))
# Out:
# 11375

# %%
# Find all unique domains 
domains = set()
links = set()
for claim in search_results.keys():
    # Exclude claims that are not in english
    claim_filtered = claim.replace("\n", " ")
    if detect(text=claim_filtered, low_memory=False)["lang"] != "en":
        continue

    for query in search_results[claim].keys():
        for _, results in search_results[claim][query].items():
            for result_object in results:
                url = result_object["link"]
                if should_filter_link(url):
                    continue
                domain_with_port = credibility_checker.extract_domain(url)
                domain = domain_with_port.split(':')[0]
                domains.add(domain)
                links.add(url)

print(len(domains), len(links))
# Out:
# Blacklisted file type:  https://ga.video.cdn.pbs.org/captions/your-vote-kuat/72887b96-4f04-40fe-a5a7-0d3c63523a6a/captions/2dDQrK_caption_en.txt
# Blacklisted file:  https://worksheets.codalab.org/rest/bundles/0xadf98bb30a99476ab56ebff3e462d4fa/contents/blob/glove.6B.100d.txt-vocab.txt
# Blacklisted file:  https://web.mit.edu/adamrose/Public/googlelist
# Blacklisted file type:  https://downloads.cs.stanford.edu/nlp/data/jiwei/data/vocab_wiki.txt
# Blacklisted file type:  https://web.stanford.edu/class/cs124/nyt_200811.txt
# Blacklisted file type:  https://www.mynavyhr.navy.mil/Portals/55/Messages/NAVADMIN/NAV2022/NAV22005.txt
# Blacklisted file type:  https://www.eecis.udel.edu/~lliao/cis320f05/dictionary.txt
# 11375 51715

# %%
# Cache the results for each domain 
for domain in tqdm(domains):
    if domain in domain_credibility:
        continue
    ssl_status = credibility_checker.get_ssl_status(domain)
    domain_age = credibility_checker.get_domain_age(domain)
    page_rank = credibility_checker.get_open_page_rank(domain)
    tld = credibility_checker.get_tld_score(domain)
    match, bias_rating, factual_rating, credibility_rating = credibility_checker.get_media_bias(domain)

    domain_credibility[domain] = {
        "ssl_status": ssl_status,
        "domain_age": domain_age,
        "page_rank": page_rank,
        "tld_score": tld,
        "matching_domain": match,
        "bias_rating": bias_rating,
        "factual_rating": factual_rating,
        "credibility_rating": credibility_rating
    }

# Save to a json file
with open("data/domain_credibility.json", "w") as f:
    json.dump(domain_credibility, f, indent=4)

# %%
from concurrent.futures import ThreadPoolExecutor

def process_domain_info(domain, credibility_checker):
    return {
            'ssl_status': credibility_checker.get_ssl_status(domain),
            'domain_age': credibility_checker.get_domain_age(domain),
            'page_rank': credibility_checker.get_open_page_rank(domain)
        }

# Cache the results for each domain 
with ThreadPoolExecutor(max_workers=10) as executor:
    future_to_domain = {
        executor.submit(process_domain_info, domain, credibility_checker): domain 
        for domain in domains
    }
    
    for future in tqdm(future_to_domain):
        domain = future_to_domain[future]
        if domain in domain_credibility:
            continue
        try:
            result = future.result()
            tld = credibility_checker.get_tld_score(domain)
            match, bias_rating, factual_rating, credibility_rating = credibility_checker.get_media_bias(domain)
            
            domain_credibility[domain] = {
                **result,
                "tld_score": tld,
                "matching_domain": match,
                "bias_rating": bias_rating,
                "factual_rating": factual_rating,
                "credibility_rating": credibility_rating
            }
        except Exception as e:
            print(f"Error processing results for {domain}: {str(e)}")

# Save to a json file
with open("data/domain_credibility.json", "w") as f:
    json.dump(domain_credibility, f, indent=4)
# Out:
#   0%|          | 0/11375 [00:00<?, ?it/s]ERROR:root:Error getting SSL status for jospi.org: [Errno 61] Connection refused
# ERROR:root:Error getting domain age for voteputnamflorida.gov after 3 attempts: [Errno 54] Connection reset by peer
# ERROR:root:Error getting SSL status for wwno.org: [Errno 61] Connection refused
#   0%|          | 1/11375 [00:03<11:13:57,  3.56s/it]ERROR:root:Error getting SSL status for mad.uscourts.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for danehousing.danecounty.gov: timed out
# ERROR:root:Error getting SSL status for law.cuny.edu: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for water.utah.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for wild.house.gov: [Errno 8] nodename nor servname provided, or not known
#   0%|          | 51/11375 [00:14<34:17,  5.50it/s]  ERROR:root:Error getting SSL status for abortion-clinics.eu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   0%|          | 55/11375 [00:16<41:48,  4.51it/s]ERROR:root:Error getting SSL status for mps.milwaukee.k12.wi.us: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   1%|          | 64/11375 [00:17<32:01,  5.89it/s]WARNING:root:No creation date found for domain abortion-clinics.eu
# WARNING:root:No creation date found for domain mps.milwaukee.k12.wi.us
#   1%|          | 82/11375 [00:22<1:06:31,  2.83it/s]ERROR:root:Error getting SSL status for community.fema.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for cop28.com: timed out
#   1%|          | 129/11375 [00:33<35:03,  5.35it/s] WARNING:root:No creation date found for domain sciencemediacentre.es
#   1%|          | 142/11375 [00:36<34:05,  5.49it/s]2025-01-27 21:23:05,239 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain staging-mobile.health.mil
#   2%|▏         | 180/11375 [00:45<44:03,  4.23it/s]  ERROR:root:Error getting SSL status for djj.state.fl.us: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for memorialhermann.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for healthleadersmedia.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   2%|▏         | 218/11375 [00:54<33:13,  5.60it/s]  ERROR:root:Error getting SSL status for nwf.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'nwf.org'. (_ssl.c:1000)
#   2%|▏         | 235/11375 [00:57<31:50,  5.83it/s]ERROR:root:Error getting SSL status for ohiocitizen.org: timed out
# WARNING:root:No creation date found for domain econstor.eu
#   2%|▏         | 266/11375 [01:05<34:48,  5.32it/s]  ERROR:root:Error getting SSL status for dodig.mil: [Errno 8] nodename nor servname provided, or not known
#   2%|▏         | 272/11375 [01:06<34:31,  5.36it/s]2025-01-27 21:23:35,301 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain dodig.mil
#   3%|▎         | 308/11375 [01:13<29:44,  6.20it/s]ERROR:root:Error getting SSL status for recruiting.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:23:43,998 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain recruiting.af.mil
# ERROR:root:Error getting SSL status for ahajournals.org: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)
# ERROR:root:Error getting SSL status for esd.whs.mil: timed out
# 2025-01-27 21:23:46,484 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain esd.whs.mil
#   3%|▎         | 356/11375 [01:25<46:44,  3.93it/s]  ERROR:root:Error getting SSL status for icelandprocruises.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'icelandprocruises.com'. (_ssl.c:1000)
# WARNING:root:No creation date found for domain vlaamsvredesinstituut.eu
# WARNING:root:No creation date found for domain gov.je
#   3%|▎         | 359/11375 [01:35<3:33:37,  1.16s/it]ERROR:root:Error getting SSL status for atlas.doe.gov: timed out
#   3%|▎         | 388/11375 [01:37<52:18,  3.50it/s]  ERROR:root:Error getting SSL status for courts.wa.gov: [Errno 8] nodename nor servname provided, or not known
#   4%|▎         | 425/11375 [01:40<25:45,  7.08it/s]ERROR:root:Error getting SSL status for goldenappleagencyinc.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1000)
#   4%|▍         | 432/11375 [01:43<53:29,  3.41it/s]WARNING:root:No creation date found for domain icc-cpi.int
#   4%|▍         | 440/11375 [01:45<45:18,  4.02it/s]ERROR:root:Error getting SSL status for cmc.marines.mil: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No PageRank data found for goshencountywy.gov
#   4%|▍         | 446/11375 [01:46<35:40,  5.11it/s]2025-01-27 21:24:14,842 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain cmc.marines.mil
#   4%|▍         | 451/11375 [01:46<28:48,  6.32it/s]ERROR:root:Error getting SSL status for blueangels.navy.mil: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'blueangels.navy.mil'. (_ssl.c:1000)
#   4%|▍         | 452/11375 [01:47<44:12,  4.12it/s]2025-01-27 21:24:16,889 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain blueangels.navy.mil
#   4%|▍         | 458/11375 [01:48<38:17,  4.75it/s]ERROR:root:Error getting SSL status for nikhef.nl: [Errno 8] nodename nor servname provided, or not known
#   4%|▍         | 474/11375 [01:52<40:57,  4.44it/s]ERROR:root:Error getting SSL status for areadevelopment.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'areadevelopment.com'. (_ssl.c:1000)
#   4%|▍         | 500/11375 [01:58<35:40,  5.08it/s]  ERROR:root:Error getting SSL status for mfa.gov.cn: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No PageRank data found for the-pope-arrested-2021.govbackgroundchecks.com
#   4%|▍         | 502/11375 [01:59<39:37,  4.57it/s]ERROR:root:Error getting SSL status for cpf.navy.mil: [Errno 8] nodename nor servname provided, or not known
#   4%|▍         | 505/11375 [01:59<34:20,  5.27it/s]2025-01-27 21:24:28,477 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain cpf.navy.mil
#   5%|▍         | 512/11375 [02:01<34:31,  5.25it/s]ERROR:root:Error getting SSL status for luetkemeyer.house.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for leginfo.ca.gov: [Errno 61] Connection refused
#   5%|▍         | 514/11375 [02:03<1:13:12,  2.47it/s]WARNING:root:No PageRank data found for profoundclarity.tumblr.com
# ERROR:root:Error getting SSL status for kirtland.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:24:37,152 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain kirtland.af.mil
#   5%|▍         | 524/11375 [02:09<1:35:58,  1.88it/s]ERROR:root:Error getting SSL status for klcc.org: [Errno 61] Connection refused
# ERROR:root:Error getting SSL status for hendryelections.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'hendryelections.org'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for courts.state.co.us: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for nicd.ac.za: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'nicd.ac.za'. (_ssl.c:1000)
#   5%|▌         | 577/11375 [02:17<29:43,  6.05it/s]  ERROR:root:Error getting SSL status for ae.china-embassy.gov.cn: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'ae.china-embassy.gov.cn'. (_ssl.c:1000)
#   5%|▌         | 589/11375 [02:19<31:47,  5.66it/s]ERROR:root:Error getting domain age for ae.china-embassy.gov.cn after 3 attempts: No matching record.
#
# WARNING:root:No creation date found for domain guncontrol.nz
#   5%|▌         | 598/11375 [02:22<37:30,  4.79it/s]ERROR:root:Error getting SSL status for wexton.house.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for fedsmallbusiness.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   6%|▌         | 631/11375 [02:31<36:35,  4.89it/s]  ERROR:root:Error getting SSL status for uchealth.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   6%|▌         | 662/11375 [02:37<34:04,  5.24it/s]WARNING:root:No creation date found for domain thekids.org.au
# WARNING:root:No creation date found for domain rm.coe.int
#   6%|▌         | 678/11375 [02:40<26:04,  6.84it/s]WARNING:root:No creation date found for domain ieep.eu
#   6%|▌         | 702/11375 [02:46<50:46,  3.50it/s]ERROR:root:Error getting SSL status for imfconnect.org: [Errno 8] nodename nor servname provided, or not known
#   6%|▌         | 703/11375 [02:50<3:08:01,  1.06s/it]ERROR:root:Error getting SSL status for honhai.com: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for puc.texas.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for airforcemedicine.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:25:30,403 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain airforcemedicine.af.mil
# WARNING:root:No creation date found for domain japan.kantei.go.jp
# WARNING:root:No creation date found for domain ipcc.ch
# ERROR:root:Error getting SSL status for ri-ara.org: [Errno 54] Connection reset by peer
# ERROR:root:Error getting SSL status for garretgraves.house.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for brandywine.psu.edu: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for japan.travel: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)
#   7%|▋         | 811/11375 [03:17<24:49,  7.09it/s]   ERROR:root:Error getting SSL status for bscc.ca.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for jstage.jst.go.jp: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain jstage.jst.go.jp
# WARNING:root:No creation date found for domain who.int
#   7%|▋         | 848/11375 [03:25<33:21,  5.26it/s]ERROR:root:Error getting SSL status for statsamerica.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'statsamerica.org'. (_ssl.c:1000)
# WARNING:root:No creation date found for domain transhub.org.au
#   8%|▊         | 866/11375 [03:29<31:18,  5.60it/s]ERROR:root:Error getting domain age for newsinitiative.withgoogle.com after 3 attempts: No match for "NEWSINITIATIVE.WITHGOOGLE.COM".
# >>> Last update of whois database: 2025-01-28T01:25:48Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# ERROR:root:Error getting SSL status for doseofrealityfl.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   8%|▊         | 878/11375 [03:31<33:27,  5.23it/s]WARNING:root:No creation date found for domain eurohealthobservatory.who.int
#   8%|▊         | 890/11375 [03:34<32:10,  5.43it/s]ERROR:root:Error getting SSL status for herbein.com: [Errno 61] Connection refused
#   8%|▊         | 891/11375 [03:34<36:30,  4.79it/s]WARNING:root:No PageRank data found for greenforestsoaps.com
#   8%|▊         | 892/11375 [03:35<57:44,  3.03it/s]WARNING:root:No creation date found for domain jjryan.com.au
# ERROR:root:Error getting SSL status for test.census.gov: [Errno 8] nodename nor servname provided, or not known
#   8%|▊         | 896/11375 [03:45<3:56:53,  1.36s/it]ERROR:root:Error getting SSL status for twc.texas.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for healthsystemtracker.org: timed out
# WARNING:root:No creation date found for domain data.who.int
# ERROR:root:Error getting SSL status for ldh.la.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#   9%|▊         | 967/11375 [03:54<32:10,  5.39it/s]  ERROR:root:Error getting SSL status for virginiaplaces.org: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)
#   9%|▊         | 976/11375 [03:57<46:07,  3.76it/s]WARNING:root:No creation date found for domain swissmedic.ch
# WARNING:root:No creation date found for domain climate.esa.int
# WARNING:root:No creation date found for domain baysidechurch.com.au
#   9%|▊         | 978/11375 [04:03<2:25:47,  1.19it/s]WARNING:root:No creation date found for domain aifs.gov.au
#   9%|▉         | 1052/11375 [04:15<48:48,  3.52it/s] WARNING:root:No creation date found for domain anu.edu.au
#   9%|▉         | 1073/11375 [04:20<34:47,  4.93it/s]ERROR:root:Error getting SSL status for controlrisks.com: [Errno 61] Connection refused
#  10%|▉         | 1091/11375 [04:23<34:55,  4.91it/s]WARNING:root:No creation date found for domain mcdonalds.co.nz
# ERROR:root:Error getting SSL status for acog.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for manchin.senate.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for kawc.org: [Errno 61] Connection refused
#  10%|▉         | 1097/11375 [04:34<2:14:59,  1.27it/s]ERROR:root:Error getting SSL status for nap.usace.army.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:27:05,543 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain nap.usace.army.mil
# ERROR:root:Error getting SSL status for health.mil: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  10%|▉         | 1114/11375 [04:39<1:17:47,  2.20it/s]2025-01-27 21:27:08,276 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain health.mil
#  10%|█         | 1155/11375 [04:41<25:01,  6.80it/s]  ERROR:root:Error getting SSL status for qcc.cuny.edu: [Errno 8] nodename nor servname provided, or not known
#  10%|█         | 1161/11375 [04:42<25:41,  6.62it/s]WARNING:root:No creation date found for domain hudoc.echr.coe.int
#  10%|█         | 1168/11375 [04:44<31:00,  5.49it/s]ERROR:root:Error getting SSL status for concordialive.com: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for codes.ohio.gov: timed out
# ERROR:root:Error getting SSL status for meuble-antika.fr: [Errno 8] nodename nor servname provided, or not known
#  10%|█         | 1171/11375 [04:49<1:06:42,  2.55it/s]WARNING:root:No creation date found for domain meuble-antika.fr
#  11%|█         | 1208/11375 [04:57<36:37,  4.63it/s]  ERROR:root:Error getting SSL status for seattlechildrens.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  11%|█         | 1229/11375 [04:59<27:20,  6.18it/s]WARNING:root:No creation date found for domain bmi.bund.de
# WARNING:root:No creation date found for domain apps.who.int
#  11%|█         | 1244/11375 [05:03<33:18,  5.07it/s]ERROR:root:Error getting SSL status for philippine-embassy.org.sg: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'philippine-embassy.org.sg'. (_ssl.c:1000)
#  11%|█▏        | 1282/11375 [05:12<29:42,  5.66it/s]  WARNING:root:No creation date found for domain home.web.cern.ch
#  11%|█▏        | 1295/11375 [05:15<30:35,  5.49it/s]ERROR:root:Error getting SSL status for ang.af.mil: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for goldmansachs.com: timed out
# 2025-01-27 21:27:46,824 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain ang.af.mil
#  12%|█▏        | 1319/11375 [05:20<27:59,  5.99it/s]  ERROR:root:Error getting SSL status for taxproplus-la.com: timed out
# ERROR:root:Error getting SSL status for academyoftucson.com: timed out
#  12%|█▏        | 1323/11375 [05:25<53:40,  3.12it/s]ERROR:root:Error getting SSL status for phc.ox.ac.uk: [Errno 8] nodename nor servname provided, or not known
#  12%|█▏        | 1349/11375 [05:27<25:41,  6.50it/s]ERROR:root:Error getting SSL status for wextradio.org: [Errno 61] Connection refused
#  12%|█▏        | 1366/11375 [05:31<32:01,  5.21it/s]WARNING:root:No creation date found for domain fbe.unimelb.edu.au
#  12%|█▏        | 1371/11375 [05:33<43:00,  3.88it/s]WARNING:root:No creation date found for domain infounitnca.iom.int
#  12%|█▏        | 1402/11375 [05:41<59:15,  2.80it/s]WARNING:root:No creation date found for domain euvsdisinfo.eu
# WARNING:root:No creation date found for domain adf.org.au
# WARNING:root:No PageRank data found for m.idahonews.com
#  12%|█▏        | 1411/11375 [05:53<2:25:17,  1.14it/s]ERROR:root:Error getting SSL status for laschoolreport.com: [Errno 61] Connection refused
#  13%|█▎        | 1456/11375 [05:56<21:05,  7.84it/s]  ERROR:root:Error getting SSL status for arcus.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'arcus.org'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for icip.iastate.edu: [Errno 8] nodename nor servname provided, or not known
#  13%|█▎        | 1484/11375 [06:03<38:37,  4.27it/s]WARNING:root:No creation date found for domain latrobe.edu.au
#  13%|█▎        | 1501/11375 [06:06<27:35,  5.97it/s]WARNING:root:No creation date found for domain intereconomics.eu
#  13%|█▎        | 1511/11375 [06:11<49:22,  3.33it/s]  WARNING:root:No PageRank data found for checkclimate.com
#  13%|█▎        | 1518/11375 [06:13<48:38,  3.38it/s]ERROR:root:Error getting SSL status for cpuc.ca.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for bpr.org: [Errno 61] Connection refused
#  13%|█▎        | 1519/11375 [06:21<2:11:41,  1.25it/s]WARNING:root:No creation date found for domain cyprus.representation.ec.europa.eu
#  14%|█▎        | 1555/11375 [06:30<1:03:17,  2.59it/s]ERROR:root:Error getting SSL status for aiaaic.org: timed out
#  14%|█▍        | 1594/11375 [06:35<29:10,  5.59it/s]  ERROR:root:Error getting SSL status for ncsc-jurystudies.org: [Errno 8] nodename nor servname provided, or not known
#  14%|█▍        | 1598/11375 [06:38<41:54,  3.89it/s]WARNING:root:No creation date found for domain stuff.co.nz
#  14%|█▍        | 1644/11375 [06:49<26:33,  6.11it/s]  WARNING:root:No creation date found for domain tewhatuora.govt.nz
#  15%|█▍        | 1679/11375 [06:58<30:01,  5.38it/s]ERROR:root:Error getting SSL status for irissmartcities.eu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1000)
#  15%|█▍        | 1684/11375 [06:59<28:00,  5.77it/s]WARNING:root:No creation date found for domain irissmartcities.eu
#  15%|█▍        | 1693/11375 [07:01<29:05,  5.55it/s]ERROR:root:Error getting SSL status for ask.usda.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  15%|█▍        | 1704/11375 [07:04<43:35,  3.70it/s]ERROR:root:Error getting SSL status for newyorkfed.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  15%|█▌        | 1707/11375 [07:09<1:58:14,  1.36it/s]WARNING:root:No creation date found for domain eda.admin.ch
# ERROR:root:Error getting SSL status for lsc.ohio.gov: timed out
#  15%|█▌        | 1715/11375 [07:16<2:05:07,  1.29it/s]ERROR:root:Error getting SSL status for digitallibrary.vassar.edu: timed out
# ERROR:root:Error getting SSL status for env-econ.net: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting domain age for d18lev1ok5leia.cloudfront.net after 3 attempts: No match for "D18LEV1OK5LEIA.CLOUDFRONT.NET".
# >>> Last update of whois database: 2025-01-28T01:29:36Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
#  15%|█▌        | 1736/11375 [07:21<1:10:03,  2.29it/s]ERROR:root:Error getting SSL status for rcinet.ca: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000)
#  15%|█▌        | 1755/11375 [07:28<1:05:01,  2.47it/s]ERROR:root:Error getting SSL status for ussc.gov: [Errno 8] nodename nor servname provided, or not known
#  16%|█▌        | 1778/11375 [07:34<52:42,  3.03it/s]  WARNING:root:No creation date found for domain drive.com.au
# ERROR:root:Error getting SSL status for hqscrecruitment.in: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'hqscrecruitment.in'. (_ssl.c:1000)
#  16%|█▌        | 1812/11375 [07:43<49:44,  3.20it/s]ERROR:root:Error getting SSL status for scgov.net: timed out
#  16%|█▌        | 1832/11375 [07:48<48:00,  3.31it/s]WARNING:root:No creation date found for domain moderndiplomacy.eu
# ERROR:root:Error getting SSL status for jacc.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'jacc.org'. (_ssl.c:1000)
#  16%|█▋        | 1862/11375 [07:56<44:25,  3.57it/s]ERROR:root:Error getting SSL status for nhpr.org: [Errno 61] Connection refused
#  17%|█▋        | 1922/11375 [08:03<26:21,  5.98it/s]ERROR:root:Error getting SSL status for ndews.umd.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# WARNING:root:No creation date found for domain echa.europa.eu
# WARNING:root:No PageRank data found for caribbeantechpioneers.buzzsprout.com
#  17%|█▋        | 1933/11375 [08:05<26:39,  5.90it/s]ERROR:root:Error getting SSL status for nro.gov: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No PageRank data found for tereniathomas.com
# ERROR:root:Error getting SSL status for archive.understandingslavery.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'archive.understandingslavery.com'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for cfpublic.org: [Errno 61] Connection refused
#  17%|█▋        | 1941/11375 [08:12<42:01,  3.74it/s]ERROR:root:Error getting SSL status for sdcda.org: timed out
#  17%|█▋        | 1983/11375 [08:17<26:49,  5.84it/s]ERROR:root:Error getting SSL status for nia.nih.gov: [Errno 8] nodename nor servname provided, or not known
#  17%|█▋        | 1990/11375 [08:18<27:45,  5.64it/s]WARNING:root:No creation date found for domain washington.mofa.go.ug
#  18%|█▊        | 1992/11375 [08:28<1:37:51,  1.60it/s]ERROR:root:Error getting SSL status for geology.utah.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  18%|█▊        | 2056/11375 [08:36<28:21,  5.48it/s]  WARNING:root:No creation date found for domain pregnancybirthbaby.org.au
#  18%|█▊        | 2068/11375 [08:38<29:45,  5.21it/s]ERROR:root:Error getting SSL status for med.navy.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:31:08,308 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain med.navy.mil
#  18%|█▊        | 2076/11375 [08:40<28:43,  5.39it/s]WARNING:root:No creation date found for domain edmo.eu
# WARNING:root:No creation date found for domain graduateinstitute.ch
#  18%|█▊        | 2094/11375 [08:43<28:26,  5.44it/s]WARNING:root:No PageRank data found for valbutlerdemings.com
# 2025-01-27 21:31:13,056 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain archive.ph
#  18%|█▊        | 2101/11375 [08:45<31:36,  4.89it/s]WARNING:root:No creation date found for domain reliefweb.int
#  19%|█▊        | 2105/11375 [08:46<26:24,  5.85it/s]ERROR:root:Error getting SSL status for hrc.army.mil: [SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1000)
# 2025-01-27 21:31:15,717 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain hrc.army.mil
# ERROR:root:Error getting SSL status for olin.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'olin.edu'. (_ssl.c:1000)
#  19%|█▊        | 2117/11375 [08:48<27:20,  5.64it/s]2025-01-27 21:31:18,039 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain ats.aq
#  19%|█▊        | 2125/11375 [08:50<30:11,  5.11it/s]WARNING:root:No creation date found for domain health.ec.europa.eu
# ERROR:root:Error getting SSL status for ohioattorneygeneral.gov: timed out
#  19%|█▉        | 2149/11375 [08:56<27:12,  5.65it/s]  WARNING:root:No creation date found for domain idea.int
# WARNING:root:No creation date found for domain vuir.vu.edu.au
# ERROR:root:Error getting SSL status for ljfo.vermont.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  19%|█▉        | 2152/11375 [09:01<58:47,  2.61it/s]ERROR:root:Error getting SSL status for amc.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:31:30,435 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain amc.af.mil
# ERROR:root:Error getting SSL status for maps.com: [SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1000)
# ERROR:root:Error getting SSL status for lamborn.house.gov: [Errno 8] nodename nor servname provided, or not known
#  19%|█▉        | 2182/11375 [09:04<26:34,  5.77it/s]2025-01-27 21:31:32,979 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain wrair.health.mil
#  19%|█▉        | 2186/11375 [09:06<41:45,  3.67it/s]ERROR:root:Error getting SSL status for todaynewsafrica.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'todaynewsafrica.com'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for ntia.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for leg.state.fl.us: timed out
# WARNING:root:No creation date found for domain doherty.edu.au
#  19%|█▉        | 2188/11375 [09:09<1:22:48,  1.85it/s]ERROR:root:Error getting SSL status for mcieast.marines.mil: [Errno 8] nodename nor servname provided, or not known
#  19%|█▉        | 2209/11375 [09:10<27:06,  5.63it/s]  2025-01-27 21:31:39,109 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain mcieast.marines.mil
#  19%|█▉        | 2211/11375 [09:13<52:15,  2.92it/s]ERROR:root:Error getting SSL status for trends.vera.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  20%|█▉        | 2254/11375 [09:20<32:09,  4.73it/s]ERROR:root:Error getting SSL status for c2f.usff.navy.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:31:51,487 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain c2f.usff.navy.mil
#  20%|█▉        | 2255/11375 [09:26<2:36:24,  1.03s/it]2025-01-27 21:31:55,230 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain cnrse.cnic.navy.mil
#  20%|██        | 2283/11375 [09:27<26:55,  5.63it/s]  WARNING:root:No creation date found for domain projects.research-and-innovation.ec.europa.eu
#  20%|██        | 2285/11375 [09:28<35:16,  4.30it/s]ERROR:root:Error getting domain age for travel.gc.ca after 3 attempts: Not found: travel.gc.ca
#
# %
# % Use of CIRA's WHOIS service is governed by the Terms of Use in its Legal
# % Notice, available at http://www.cira.ca/legal-notice/?lang=en
# %
# % (c) 2025 Canadian Internet Registration Authority, (http://www.cira.ca/)
#
#  20%|██        | 2296/11375 [09:30<25:37,  5.91it/s]ERROR:root:Error getting SSL status for familymedicine.uw.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  20%|██        | 2322/11375 [09:37<47:58,  3.15it/s]WARNING:root:No creation date found for domain diwan.gov.qa
# WARNING:root:No creation date found for domain allergy.org.au
#  21%|██        | 2344/11375 [09:41<25:44,  5.85it/s]  ERROR:root:Error getting SSL status for bluefieldwv.gov: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)
# ERROR:root:Error getting SSL status for rubengallego.house.gov: [Errno 8] nodename nor servname provided, or not known
#  21%|██        | 2378/11375 [09:51<31:24,  4.77it/s]  ERROR:root:Error getting SSL status for poh.usace.army.mil: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting domain age for rturner229.blogspot.com after 3 attempts: [Errno 54] Connection reset by peer
# 2025-01-27 21:32:21,408 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain poh.usace.army.mil
# ERROR:root:Error getting SSL status for populationmedicine.eu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# WARNING:root:No creation date found for domain populationmedicine.eu
# ERROR:root:Error getting SSL status for niehs.nih.gov: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain br.de
#  21%|██        | 2389/11375 [09:59<53:13,  2.81it/s]ERROR:root:Error getting SSL status for fmcsa.dot.gov: timed out
#  21%|██        | 2410/11375 [10:02<38:33,  3.87it/s]ERROR:root:Error getting SSL status for dyson.com: _ssl.c:983: The handshake operation timed out
#  21%|██▏       | 2437/11375 [10:05<26:45,  5.57it/s]ERROR:root:Error getting SSL status for dailyiowan.lib.uiowa.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  22%|██▏       | 2467/11375 [10:12<27:34,  5.39it/s]ERROR:root:Error getting SSL status for ip-watch.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'ip-watch.org'. (_ssl.c:1000)
#  22%|██▏       | 2474/11375 [10:13<27:53,  5.32it/s]ERROR:root:Error getting SSL status for ams.usda.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'ams.usda.gov'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for normanackroyd.com: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)
#  22%|██▏       | 2491/11375 [10:17<23:42,  6.24it/s]WARNING:root:No creation date found for domain csd.k12.wi.us
#  22%|██▏       | 2505/11375 [10:21<32:51,  4.50it/s]  2025-01-27 21:32:52,441 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain patrasapartments.gr
# ERROR:root:Error getting SSL status for chicagofed.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  22%|██▏       | 2552/11375 [10:32<28:34,  5.15it/s]  2025-01-27 21:33:01,082 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 61] Connection refused
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 61] Connection refused
# WARNING:root:No creation date found for domain elsevier.es
#  22%|██▏       | 2556/11375 [10:33<32:21,  4.54it/s]ERROR:root:Error getting SSL status for gatesnotes.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  22%|██▏       | 2557/11375 [10:34<38:46,  3.79it/s]ERROR:root:Error getting SSL status for law.gwu.edu: [Errno 8] nodename nor servname provided, or not known
#  23%|██▎       | 2574/11375 [10:37<25:49,  5.68it/s]WARNING:root:No creation date found for domain politico.eu
#  23%|██▎       | 2620/11375 [10:49<31:59,  4.56it/s]  ERROR:root:Error getting SSL status for tsl.texas.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# WARNING:root:No creation date found for domain chelwest.nhs.uk
# ERROR:root:Error getting SSL status for frommers.com: timed out
#  23%|██▎       | 2624/11375 [10:59<1:26:32,  1.69it/s]ERROR:root:Error getting SSL status for fldoe.org: timed out
# ERROR:root:Error getting SSL status for kaxe.org: [Errno 61] Connection refused
#  23%|██▎       | 2650/11375 [11:01<43:23,  3.35it/s]  ERROR:root:Error getting SSL status for armyupress.army.mil: [Errno 8] nodename nor servname provided, or not known
#  23%|██▎       | 2660/11375 [11:02<34:50,  4.17it/s]2025-01-27 21:33:31,157 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain armyupress.army.mil
# ERROR:root:Error getting SSL status for extension.msstate.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for dentonisd.org: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for gop.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  24%|██▎       | 2698/11375 [11:09<25:31,  5.67it/s]  ERROR:root:Error getting SSL status for marines.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:33:38,650 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain marines.mil
# ERROR:root:Error getting SSL status for npshistory.com: timed out
#  24%|██▍       | 2723/11375 [11:16<27:58,  5.16it/s]ERROR:root:Error getting SSL status for afgsc.af.mil: [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain firearmssafetyauthority.govt.nz
# 2025-01-27 21:33:44,864 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain afgsc.af.mil
# ERROR:root:Error getting SSL status for aphis.usda.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for bootcamp.navy.mil: [Errno 8] nodename nor servname provided, or not known
#  24%|██▍       | 2734/11375 [11:18<27:52,  5.17it/s]2025-01-27 21:33:46,826 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain bootcamp.navy.mil
#  24%|██▍       | 2742/11375 [11:19<24:49,  5.79it/s]ERROR:root:Error getting SSL status for usmcu.edu: timed out
# WARNING:root:No creation date found for domain defendnz.co.nz
# WARNING:root:No PageRank data found for shopcode.tumblr.com
#  25%|██▍       | 2790/11375 [11:31<27:44,  5.16it/s]  ERROR:root:Error getting SSL status for fd.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'fd.org'. (_ssl.c:1000)
#  25%|██▍       | 2800/11375 [11:34<32:41,  4.37it/s]WARNING:root:No creation date found for domain nato.int
# ERROR:root:Error getting SSL status for osa.state.mn.us: [Errno 54] Connection reset by peer
# ERROR:root:Error getting SSL status for girlscoutsaz.org: timed out
# ERROR:root:Error getting SSL status for mededportal.org: _ssl.c:983: The handshake operation timed out
#  25%|██▍       | 2802/11375 [11:44<2:01:17,  1.18it/s]ERROR:root:Error getting SSL status for broadbandusa.ntia.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  25%|██▍       | 2809/11375 [11:45<1:21:59,  1.74it/s]ERROR:root:Error getting SSL status for ncleg.gov: timed out
#  25%|██▍       | 2838/11375 [11:50<40:29,  3.51it/s]  ERROR:root:Error getting SSL status for 15wing.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 21:34:21,537 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain 15wing.af.mil
#  25%|██▌       | 2849/11375 [11:56<52:22,  2.71it/s]WARNING:root:No creation date found for domain mcri.edu.au
#  25%|██▌       | 2898/11375 [12:00<24:40,  5.73it/s]ERROR:root:Error getting SSL status for wuwm.com: [Errno 61] Connection refused
#  26%|██▌       | 2913/11375 [12:04<27:17,  5.17it/s]ERROR:root:Error getting SSL status for courts.state.md.us: [Errno 8] nodename nor servname provided, or not known
#  26%|██▌       | 2921/11375 [12:05<23:04,  6.11it/s]WARNING:root:No creation date found for domain interregeurope.eu
#  26%|██▌       | 2927/11375 [12:07<43:01,  3.27it/s]WARNING:root:No creation date found for domain performinglines.org.au
#  26%|██▌       | 2936/11375 [12:09<28:34,  4.92it/s]WARNING:root:No creation date found for domain iss.europa.eu
#  26%|██▌       | 2981/11375 [12:19<31:23,  4.46it/s]ERROR:root:Error getting SSL status for saintsresource.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'saintsresource.com'. (_ssl.c:1000)
# ...
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# ERROR:root:Error getting SSL status for 349amw.afrc.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 22:04:31,421 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain 349amw.afrc.af.mil
# ERROR:root:Error getting SSL status for stlouisfed.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# ERROR:root:Error getting SSL status for burgess.house.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting domain age for science.gc.ca after 3 attempts: Not found: science.gc.ca
#
# %
# % Use of CIRA's WHOIS service is governed by the Terms of Use in its Legal
# % Notice, available at http://www.cira.ca/legal-notice/?lang=en
# %
# % (c) 2025 Canadian Internet Registration Authority, (http://www.cira.ca/)
#
# ERROR:root:Error getting SSL status for teslarati.com: [Errno 61] Connection refused
# ERROR:root:Error getting SSL status for oregonlegislature.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'oregonlegislature.gov'. (_ssl.c:1000)
# WARNING:root:No creation date found for domain food.ec.europa.eu
# ERROR:root:Error getting SSL status for nasbo.org: [Errno 61] Connection refused
# ERROR:root:Error getting SSL status for ed.ac.uk: timed out
# 2025-01-27 22:04:46,958 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain micicinitiative.iom.int
# ERROR:root:Error getting domain age for holodomormuseum.org.ua after 3 attempts: Cannot subtract tz-naive and tz-aware datetime-like objects.
#  92%|█████████▏| 10511/11375 [42:20<01:53,  7.63it/s]WARNING:root:No PageRank data found for garthbrooks2022.com
#  93%|█████████▎| 10572/11375 [42:22<01:07, 11.88it/s]ERROR:root:Error getting SSL status for nasic.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 22:04:51,675 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain nasic.af.mil
# WARNING:root:No creation date found for domain foxsports.com.au
# ERROR:root:Error getting SSL status for wrvo.org: [Errno 61] Connection refused
# WARNING:root:No creation date found for domain viz.berlin.de
#  94%|█████████▎| 10639/11375 [42:38<01:49,  6.74it/s]ERROR:root:Error getting SSL status for tc.columbia.edu: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'tc.columbia.edu'. (_ssl.c:1000)
# 2025-01-27 22:05:07,850 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain history.navy.mil
#  94%|█████████▎| 10660/11375 [42:42<01:47,  6.63it/s]2025-01-27 22:05:11,781 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain mycg.uscg.mil
#  94%|█████████▍| 10674/11375 [42:46<02:21,  4.95it/s]ERROR:root:Error getting SSL status for girlscoutsgcnwi.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'girlscoutsgcnwi.org'. (_ssl.c:1000)
#  94%|█████████▍| 10695/11375 [42:50<02:11,  5.17it/s]ERROR:root:Error getting SSL status for readme.readmedia.com: [Errno 61] Connection refused
# ERROR:root:Error getting SSL status for altoona.k12.wi.us: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'altoona.k12.wi.us'. (_ssl.c:1000)
# ERROR:root:Error getting SSL status for wzb.eu: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)
# WARNING:root:No creation date found for domain wzb.eu
# 2025-01-27 22:05:25,533 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain altoona.k12.wi.us
# ERROR:root:Error getting SSL status for fs.ncaa.org: _ssl.c:983: The handshake operation timed out
# ERROR:root:Error getting SSL status for securityhealth.org: [SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1000)
# 2025-01-27 22:05:28,403 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain voz.us
#  94%|█████████▍| 10727/11375 [43:04<03:35,  3.01it/s]WARNING:root:No creation date found for domain england.nhs.uk
#  95%|█████████▍| 10765/11375 [43:09<01:41,  5.99it/s]ERROR:root:Error getting SSL status for qfc.com: timed out
#  95%|█████████▌| 10808/11375 [43:18<01:35,  5.91it/s]ERROR:root:Error getting SSL status for pa.ng.mil: timed out
# 2025-01-27 22:05:51,414 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain pa.ng.mil
# ERROR:root:Error getting domain age for parliament.go.ug after 3 attempts: [Errno 54] Connection reset by peer
# ERROR:root:Error getting SSL status for health.wnylc.com: timed out
#  95%|█████████▌| 10831/11375 [43:28<02:11,  4.12it/s]ERROR:root:Error getting SSL status for sapr.mil: _ssl.c:983: The handshake operation timed out
# 2025-01-27 22:05:58,101 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain sapr.mil
#  95%|█████████▌| 10852/11375 [43:31<01:40,  5.23it/s]WARNING:root:No creation date found for domain climate.ec.europa.eu
#  96%|█████████▌| 10886/11375 [43:41<01:45,  4.63it/s]WARNING:root:No creation date found for domain uq.edu.au
# ERROR:root:Error getting SSL status for kim.house.gov: [Errno 8] nodename nor servname provided, or not known
# ERROR:root:Error getting SSL status for sweetbeet.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'sweetbeet.com'. (_ssl.c:1000)
#  96%|█████████▌| 10940/11375 [43:58<03:53,  1.86it/s]ERROR:root:Error getting SSL status for esteri.it: [Errno 8] nodename nor servname provided, or not known
#  96%|█████████▋| 10965/11375 [44:01<01:23,  4.93it/s]ERROR:root:Error getting SSL status for accessdata.fda.gov: [Errno 8] nodename nor servname provided, or not known
#  97%|█████████▋| 10994/11375 [44:08<01:21,  4.66it/s]ERROR:root:Error getting SSL status for richmondfed.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  97%|█████████▋| 11016/11375 [44:13<01:03,  5.63it/s]ERROR:root:Error getting SSL status for consumerfinance.gov: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  97%|█████████▋| 11035/11375 [44:18<01:15,  4.48it/s]ERROR:root:Error getting SSL status for nickel.house.gov: [Errno 8] nodename nor servname provided, or not known
#  97%|█████████▋| 11041/11375 [44:18<00:56,  5.89it/s]ERROR:root:Error getting SSL status for floridagovernorsmansion.com: [Errno 8] nodename nor servname provided, or not known
#  97%|█████████▋| 11045/11375 [44:20<01:40,  3.29it/s]ERROR:root:Error getting SSL status for 8af.af.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 22:06:50,955 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain 8af.af.mil
# 2025-01-27 22:06:58,733 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain tacobellmenuprices.us
# 2025-01-27 22:06:59,139 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain rangemedia.co
# WARNING:root:No creation date found for domain thecitizen.co.tz
# ERROR:root:Error getting SSL status for hmc.harvard.edu: timed out
#  98%|█████████▊| 11110/11375 [44:38<00:47,  5.58it/s]WARNING:root:No creation date found for domain factiverse.ghost.io
# ERROR:root:Error getting SSL status for hbscdallas.org: timed out
#  98%|█████████▊| 11147/11375 [44:44<00:36,  6.17it/s]ERROR:root:Error getting SSL status for dia.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 22:07:14,224 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain dia.mil
# ERROR:root:Error getting SSL status for ilsenateredistricting.com: timed out
# 2025-01-27 22:07:16,559 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain aeon.co
# 2025-01-27 22:07:17,331 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain sigar.mil
#  98%|█████████▊| 11152/11375 [44:49<01:02,  3.58it/s]ERROR:root:Error getting SSL status for psc.state.md.us: timed out
# 2025-01-27 22:07:19,517 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# WARNING:root:No creation date found for domain psc.state.md.us
#  98%|█████████▊| 11191/11375 [44:54<00:29,  6.29it/s]WARNING:root:No creation date found for domain www3.nhk.or.jp
#  98%|█████████▊| 11202/11375 [44:56<00:37,  4.56it/s]WARNING:root:No PageRank data found for explore.britannica.com
#  98%|█████████▊| 11204/11375 [44:57<00:36,  4.65it/s]WARNING:root:No creation date found for domain aph.gov.au
#  99%|█████████▊| 11208/11375 [44:59<00:54,  3.05it/s]WARNING:root:No creation date found for domain efpia.eu
#  99%|█████████▊| 11214/11375 [44:59<00:32,  4.94it/s]2025-01-27 22:07:28,933 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 54] Connection reset by peer
#  99%|█████████▊| 11218/11375 [45:00<00:37,  4.24it/s]WARNING:root:No creation date found for domain dhs.state.il.us
#  99%|█████████▊| 11221/11375 [45:01<00:33,  4.53it/s]WARNING:root:No PageRank data found for adititandon.medium.com
#  99%|█████████▊| 11222/11375 [45:02<00:59,  2.58it/s]WARNING:root:No creation date found for domain edps.europa.eu
#  99%|█████████▊| 11232/11375 [45:04<00:35,  4.04it/s]WARNING:root:No PageRank data found for dunhamlawaz.com
#  99%|█████████▉| 11247/11375 [45:07<00:32,  3.93it/s]ERROR:root:Error getting SSL status for vec.virginia.gov: [Errno 54] Connection reset by peer
#  99%|█████████▉| 11252/11375 [45:08<00:23,  5.28it/s]ERROR:root:Error getting SSL status for advanresearch.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#  99%|█████████▉| 11266/11375 [45:11<00:23,  4.56it/s]ERROR:root:Error getting SSL status for nationalguard.mil: [Errno 8] nodename nor servname provided, or not known
# 2025-01-27 22:07:40,811 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 8] nodename nor servname provided, or not known
# WARNING:root:No creation date found for domain nationalguard.mil
#  99%|█████████▉| 11274/11375 [45:12<00:16,  6.19it/s]WARNING:root:No creation date found for domain greenvehicleguide.gov.au
# WARNING:root:No creation date found for domain mumsgrapevine.com.au
#  99%|█████████▉| 11283/11375 [45:15<00:18,  4.86it/s]ERROR:root:Error getting SSL status for www-thedailybeast-com.lib3.cgmh.org.tw: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www-thedailybeast-com.lib3.cgmh.org.tw'. (_ssl.c:1000)
#  99%|█████████▉| 11293/11375 [45:16<00:11,  7.06it/s]WARNING:root:No PageRank data found for www-thedailybeast-com.lib3.cgmh.org.tw
#  99%|█████████▉| 11305/11375 [45:19<00:12,  5.42it/s]ERROR:root:Error getting SSL status for ncci.com: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'ncci.com'. (_ssl.c:1000)
# 100%|█████████▉| 11324/11375 [45:23<00:10,  5.04it/s]WARNING:root:No creation date found for domain uni-bonn.de
# WARNING:root:No creation date found for domain consilium.europa.eu
# 100%|█████████▉| 11336/11375 [45:27<00:10,  3.60it/s]ERROR:root:Error getting SSL status for naacpldf.org: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
# WARNING:root:No creation date found for domain jfcnorfolk.nato.int
# 2025-01-27 22:08:04,289 - whois.whois - ERROR - Error trying to connect to socket: closing socket - timed out
# ERROR:whois.whois:Error trying to connect to socket: closing socket - timed out
# WARNING:root:No creation date found for domain flatearth.ws
# 100%|██████████| 11375/11375 [45:36<00:00,  4.16it/s]

# %%
import matplotlib.pyplot as plt

# Do an aggregation of the scores per claim
save_path = "../data/claim_credibility.json"
if os.path.exists(save_path):
    with open(save_path, "r") as f:
        claim_credibility = json.load(f)
else:
    claim_credibility = {}


if os.path.exists("../data/domain_credibility.json"):
    with open("../data/domain_credibility.json", "r") as f:
        domain_credibility = json.load(f)
else:
    domain_credibility = {}

# %%
unique_domains = set()
for claim in tqdm(search_results.keys()):
    # Exclude claims that are not in english
    claim_filtered = claim.replace("\n", " ")
    if detect(text=claim_filtered, low_memory=False)["lang"] != "en":
        continue

    credibility_rating = []
    factual_rating = []
    bias_rating = []
    domain_age = []
    tld_score = []
    page_rank = []
    for query in search_results[claim].keys():
        for _, results in search_results[claim][query].items():
            for result_object in results:
                url = result_object["link"]
                if should_filter_link(url):
                    continue
                domain_with_port = credibility_checker.extract_domain(url)
                domain = domain_with_port.split(':')[0]
                val = domain_credibility[domain]
                credibility_rating.append(val["credibility_rating"])
                factual_rating.append(val["factual_rating"])
                bias_rating.append(val["bias_rating"])
                domain_age.append(val["domain_age"])
                tld_score.append(val["tld_score"])
                page_rank.append(val["page_rank"])

    # Apply mapping
    credibility_scores = [credibility_checker.credibility_scores_map.get(x) for x in credibility_rating]
    factual_scores = [credibility_checker.factual_ratings_map.get(x) for x in factual_rating]
    bias_scores = [credibility_checker.bias_scores_map.get(x) for x in bias_rating]

    # Calculate the average
    claim_credibility[claim] = {
        "domain_age": sum(filter(None, domain_age)) / len(list(filter(None, domain_age))) if any(domain_age) else None,
        "tld_score": sum(filter(None, tld_score)) / len(list(filter(None, tld_score))) if any(tld_score) else None,
        "page_rank": sum(filter(None, page_rank)) / len(list(filter(None, page_rank))) if any(page_rank) else None,
        "bias_rating_score": sum(filter(None, bias_scores)) / len(list(filter(None, bias_scores))) if any(bias_scores) else None,
        "factual_rating_score": sum(filter(None, factual_scores)) / len(list(filter(None, factual_scores))) if any(factual_scores) else None,
        "credibility_rating_score": sum(filter(None, credibility_scores)) / len(list(filter(None, credibility_scores))) if any(credibility_scores) else None
    }

with open("../data/claim_credibility.json", "w") as f:
    json.dump(claim_credibility, f, indent=4)
# Out:
#  34%|███▍      | 908/2684 [00:00<00:00, 4633.01it/s]
# Blacklisted file type:  https://ga.video.cdn.pbs.org/captions/your-vote-kuat/72887b96-4f04-40fe-a5a7-0d3c63523a6a/captions/2dDQrK_caption_en.txt
# Blacklisted file:  https://worksheets.codalab.org/rest/bundles/0xadf98bb30a99476ab56ebff3e462d4fa/contents/blob/glove.6B.100d.txt-vocab.txt
# Blacklisted file:  https://web.mit.edu/adamrose/Public/googlelist
# Blacklisted file type:  https://downloads.cs.stanford.edu/nlp/data/jiwei/data/vocab_wiki.txt
# Blacklisted file type:  https://web.stanford.edu/class/cs124/nyt_200811.txt
# Blacklisted file type:  https://www.mynavyhr.navy.mil/Portals/55/Messages/NAVADMIN/NAV2022/NAV22005.txt
# 100%|██████████| 2684/2684 [00:00<00:00, 4864.63it/s]
# Blacklisted file type:  https://www.eecis.udel.edu/~lliao/cis320f05/dictionary.txt

# %% [markdown]
# ## Data Analysis

# %%
import json
import matplotlib.pyplot as plt
with open('../data/dataset_politifact.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

credibility_scores = []
domain_ages = []
bias_scores = []
tld_scores = []
page_ranks = []
factual_scores = []

label_map = {
    "True": "True",
    "Mostly True": "Mixed",
    "Half True": "Mixed",       # in case 'Half True' is used
    "Mostly False": "Mixed",
    "False": "False",
    "Pants on Fire": "False"        # mapped to "False"
}

for claim_obj in data:
    credibility_scores.append(claim_obj["domain_authority_metrics"]["credibility_rating_score"])
    domain_ages.append(claim_obj["domain_authority_metrics"]["domain_age"])
    bias_scores.append(claim_obj["domain_authority_metrics"]["bias_rating_score"])
    tld_scores.append(claim_obj["domain_authority_metrics"]["tld_score"])
    page_ranks.append(claim_obj["domain_authority_metrics"]["page_rank"])
    factual_scores.append(claim_obj["domain_authority_metrics"]["factual_rating_score"])

# %%
# Replace None with 0
credibility_scores = [x if x is not None else 0 for x in credibility_scores]

# Create labels mapping
credibility_labels = {
    0: 'cannot be determined',
    1: 'low credibility', 
    2: 'mixed credibility',
    3: 'medium credibility',
    4: 'high credibility'
}

plt.xlabel("Credibility Score")
plt.ylabel("Frequency")
plt.hist(credibility_scores, bins=len(credibility_labels), align='left')

# Add x-axis labels
plt.xticks(range(len(credibility_labels)), list(credibility_labels.values()), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# Remove the None values
domain_ages = [x for x in domain_ages if x is not None]

plt.xlabel("Domain Age")
plt.ylabel("Frequency")
plt.hist(domain_ages)
plt.show()

# %%
# Replace bias score with 0 the None values
bias_scores = [x if x is not None else 0 for x in bias_scores]

# Create labels mapping
bias_labels = {
    0: "cannot be determined",
    1: "left",
    2: "leftcenter",
    3: "center/pro-science",
    4: "right-center",
    5: "right/consp/fnews",
}

plt.xlabel("Bias Score")
plt.ylabel("Frequency")
plt.hist(bias_scores, bins=len(bias_labels), align='left')

# Add x-axis labels
plt.xticks(range(len(bias_labels)), list(bias_labels.values()), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# Factual scores
factual_scores = [x if x is not None else 0 for x in factual_scores]

factual_labels = {
    0: "cannot be determined",
    1: "very low",
    2: "low",
    3: "mixed",
    4: "mostly factual",
    5: "high",
    6: "very high",
}

plt.xlabel("Factual Score")
plt.ylabel("Frequency")
plt.hist(factual_scores, bins=len(factual_labels), align='left')

# Add x-axis labels
plt.xticks(range(len(factual_labels)), list(factual_labels.values()), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# Remove the None values
page_ranks = [x for x in page_ranks if x is not None]

plt.xlabel("Page Rank")
plt.ylabel("Frequency")
plt.hist(page_ranks)
plt.show()

# %%
# tld scores
tld_scores = [x for x in tld_scores if x is not None]

plt.xlabel("TLD Score")
plt.ylabel("Frequency")
plt.hist(tld_scores)
plt.show()
